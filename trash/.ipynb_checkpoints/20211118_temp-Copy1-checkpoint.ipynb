# %% [markdown]
# # Scikit-downscale

# %% [markdown]
# ## Prepare models

# %% [markdown]
# This first cell just imports some libraries and get's things setup for our analysis to come.This first cell just imports some libraries and get's things setup for our analysis to come.

# %%
# close warming info
import warnings
warnings.filterwarnings("ignore")
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")  # sklearn

import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd

import numpy as np

from utils import get_sample_data

sns.set(style='darkgrid')

# %% [markdown]
# In the cell below, we'll create nine different downscaling models, some from Scikit-downscale and some from Scikit-learn.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

from skdownscale.pointwise_models import PureAnalog, AnalogRegression
from skdownscale.pointwise_models import BcsdTemperature, BcsdPrecipitation


models = {
    'GARD: PureAnalog-best-1': PureAnalog(kind='best_analog', n_analogs=1),
    'GARD: PureAnalog-sample-10': PureAnalog(kind='sample_analogs', n_analogs=10),
    'GARD: PureAnalog-weight-10': PureAnalog(kind='weight_analogs', n_analogs=10),
    'GARD: PureAnalog-weight-100': PureAnalog(kind='weight_analogs', n_analogs=100),
    'GARD: PureAnalog-mean-10': PureAnalog(kind='mean_analogs', n_analogs=10),
    'GARD: AnalogRegression-100': AnalogRegression(n_analogs=100),
    'GARD: LinearRegression': LinearRegression(),
    'BCSD: BcsdTemperature': BcsdTemperature(return_anoms=False),
    'Sklearn: RandomForestRegressor': RandomForestRegressor(random_state=0)
}

train_slice = slice('1980-01-01', '1989-12-31')
predict_slice = slice('1990-01-01', '1999-12-31')

# %% [markdown]
# ## Activate CUPs for parallel computing

# %% [markdown]
# Step 1: Start a Dask Cluster. Xarray and the `PointWiseDownscaler` will make use of this cluster when it comes time to load input data and train/predict downscaling models.

# %%
from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:39647' processes=10 threads=80, memory=503.62 GiB>

# %% [markdown]
# ## Make a choice of the downscale model

# %%
from skdownscale.pointwise_models import PointWiseDownscaler
from dask.diagnostics import ProgressBar

# model = PointWiseDownscaler(BcsdTemperature(return_anoms=False))
# model = PointWiseDownscaler(RandomForestRegressor(random_state=0))
model = PointWiseDownscaler(PureAnalog(kind='best_analog', n_analogs=1))
# model = PointWiseDownscaler(PureAnalog(kind='sample_analogs', n_analogs=10))

model
# Out:
# <skdownscale.PointWiseDownscaler>
#   Fit Status: False
#   Model:
#     PureAnalog(n_analogs=1)

# %% [markdown]
# ## Malaysia/Philippines/Thailand/Indonesia

# %%
# parameters
train_slice = slice('2005', '2007')  # train time range   '1981', '1983'
holdout_slice = slice('2053', '2055')  # prediction time range

CITY_CENTER = pd.DataFrame(data={
    'CITY': ['KUALA_LUMPUR','MANILA','BANGKOK','JAKARDA'],
    'LAT' : [3.08  , 14.60 ,13.76 , -6.21 ],
    'LON' : [101.67, 120.99,100.49, 106.81]
                               })
# Malaysia
#NNN,SSS,WWW,EEE = 8.5,-0.5,98.5,120.5

# Philippines
# NNN,SSS,WWW,EEE = 23.5,3.5,115.5,128.5

# Thailand
# NNN,SSS,WWW,EEE = 21.5, 4.5, 96.5, 106.5

# Indonesia
NNN,SSS,WWW,EEE = 6.5, -12.5, 94.5, 142.5

# bounding box of downscaling region
lon_slice = slice(WWW, EEE) 
lat_slice = slice(NNN, SSS)

# chunk shape for dask execution (time must be contiguous, ie -1)
chunks = {'lat': 10, 'lon': 10, 'time': -1}

# %%
import ee
import wxee

# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()

# singapore: 1.3521° N, 103.8198° E
region = ee.Geometry.Polygon([[
    [WWW, NNN],
    [WWW, SSS],
    [EEE, SSS],
    [EEE, NNN]
]])
era5_2mt = ee.ImageCollection('ECMWF/ERA5/DAILY')
era5_2mt = era5_2mt.select('maximum_2m_air_temperature')
era5_2mt = era5_2mt.filterDate("2005-01-01", "2008-01-01") # here we should add one more time for the end point
obs_subset=era5_2mt.wx.to_xarray(region=region)
obs_subset=obs_subset['maximum_2m_air_temperature']
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=qR28p-FkRO7X1bO7KfIPnXneWQE8rbI932zB1ywUa5c&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=qR28p-FkRO7X1bO7KfIPnXneWQE8rbI932zB1ywUa5c&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code:  4/1AX4XfWhcc_OkVK4SeBghGxfPACZP1JhAXp7zTukWC1nfuFaS59kLhoQg20Y
# Successfully saved authorization token.
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=qR28p-FkRO7X1bO7KfIPnXneWQE8rbI932zB1ywUa5c&code_challenge_method=S256'
# Requesting data:   0%|          | 0/1095 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/1095 [00:00<?, ?it/s]

# %%
obs_subset=obs_subset.rename({'x': 'lon','y': 'lat'})

# %%
obs_subset.isel(time=0).plot()

# %% [markdown]
# Set the downscale resolution here. Example: CHANGE_INTERVAL=0.02 is for a resolution of 1deg*0.02~2km

# %%
CHANGE_INTERVAL=0.02#0.005
obs_subset = obs_subset.interp(lat=np.arange(NNN, SSS-CHANGE_INTERVAL,-CHANGE_INTERVAL),lon=np.arange(WWW, EEE+CHANGE_INTERVAL,CHANGE_INTERVAL),kwargs={"fill_value": "extrapolate"})
# obs_subset.interp(lat=np.arange(NNN, SSS-CHANGE_INTERVAL,-CHANGE_INTERVAL),lon=np.arange(WWW, EEE+CHANGE_INTERVAL,CHANGE_INTERVAL)).isel(time=0).plot()

# %%
obs_subset.isel(time=0).plot()

# %% [markdown]
# Load our training/prediction data.

# %%
import intake_esm
import intake

# search the cmip6 catalog
col = intake.open_esm_datastore("https://storage.googleapis.com/cmip6/pangeo-cmip6.json")
# cat = col.search(experiment_id=['historical', 'ssp585'], table_id='day', variable_id='tasmax',
#                  grid_label='gn')
cat = col.search(experiment_id=['historical','ssp585'], table_id='day', variable_id='tasmax',member_id='r1i1p1f1',
                 grid_label='gn')

# access the data and do some cleanup
ds_model = cat['CMIP.CSIRO-ARCCSS.ACCESS-CM2.historical.day.gn'].to_dask().squeeze(drop=True).drop(['height', 'lat_bnds', 'lon_bnds', 'time_bnds'])
ds_model.lon.values[ds_model.lon.values > 180] -= 360
ds_model = ds_model.roll(lon=72, roll_coords=True)

# regional subsets, ready for downscaling
train_subset = ds_model['tasmax'].sel(time=train_slice).interp_like(obs_subset.isel(time=0, drop=True), method='linear')
train_subset['time']=pd.to_datetime(train_subset['time'].dt.strftime('%Y-%m-%d'))
# train_subset['time'] = train_subset.indexes['time'].to_datetimeindex()
train_subset = train_subset.resample(time='1d').mean().load(scheduler='threads').chunk(chunks)


# access the data and do some cleanup
ds_model = cat['ScenarioMIP.CSIRO-ARCCSS.ACCESS-CM2.ssp585.day.gn'].to_dask().squeeze(drop=True).drop(['height', 'lat_bnds', 'lon_bnds', 'time_bnds'])
ds_model.lon.values[ds_model.lon.values > 180] -= 360
ds_model = ds_model.roll(lon=72, roll_coords=True)

holdout_subset = ds_model['tasmax'].sel(time=holdout_slice).interp_like(obs_subset.isel(time=0, drop=True), method='linear')
holdout_subset['time']=pd.to_datetime(holdout_subset['time'].dt.strftime('%Y-%m-%d'))
# holdout_subset['time'] = holdout_subset.indexes['time'].to_datetimeindex()
holdout_subset = holdout_subset.resample(time='1d').mean().load(scheduler='threads').chunk(chunks)

# display
# display(train_subset)
# train_subset.isel(time=0).plot()
display(train_subset)
holdout_subset.isel(time=0).plot()
# Out:
# /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/xarray/coding/times.py:527: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/xarray/coding/times.py:527: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/xarray/core/indexing.py:419: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)
# <xarray.DataArray 'tasmax' (time: 1095, lat: 951, lon: 2402)>
# dask.array<xarray-<this-array>, shape=(1095, 951, 2402), dtype=float32, chunksize=(1095, 10, 10), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 2005-01-01 2005-01-02 ... 2007-12-31
#   * lat      (lat) float64 6.5 6.48 6.46 6.44 ... -12.44 -12.46 -12.48 -12.5
#   * lon      (lon) float64 94.5 94.52 94.54 94.56 ... 142.5 142.5 142.5 142.5

# %% [markdown]
# Check the available CMIP6 models

# %%
cat = col.search(experiment_id=['historical','ssp585'], table_id='day', variable_id='tasmax',grid_label='gn')
cat.df
# Out:
#      activity_id institution_id      source_id experiment_id member_id  \
# 0           CMIP      NASA-GISS    GISS-E2-1-G    historical  r1i1p1f1
# 1           CMIP            BCC    BCC-CSM2-MR    historical  r2i1p1f1
# 2           CMIP            BCC    BCC-CSM2-MR    historical  r3i1p1f1
# 3           CMIP            BCC    BCC-CSM2-MR    historical  r1i1p1f1
# 4           CMIP            AWI  AWI-CM-1-1-MR    historical  r2i1p1f1
# ..           ...            ...            ...           ...       ...
# 388  ScenarioMIP            MRI     MRI-ESM2-0        ssp585  r5i1p1f1
# 389  ScenarioMIP            MRI     MRI-ESM2-0        ssp585  r3i1p1f1
# 390  ScenarioMIP            MRI     MRI-ESM2-0        ssp585  r4i1p1f1
# 391         CMIP            MRI     MRI-ESM2-0    historical  r6i1p1f1
# 392  ScenarioMIP            MRI     MRI-ESM2-0        ssp585  r2i1p1f1
#
#     table_id variable_id grid_label  \
# 0        day      tasmax         gn
# 1        day      tasmax         gn
# 2        day      tasmax         gn
# 3        day      tasmax         gn
# 4        day      tasmax         gn
# ..       ...         ...        ...
# 388      day      tasmax         gn
# 389      day      tasmax         gn
# 390      day      tasmax         gn
# 391      day      tasmax         gn
# 392      day      tasmax         gn
#
#                                                 zstore  dcpp_init_year  \
# 0    gs://cmip6/CMIP6/CMIP/NASA-GISS/GISS-E2-1-G/hi...             NaN
# 1    gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 2    gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 3    gs://cmip6/CMIP6/CMIP/BCC/BCC-CSM2-MR/historic...             NaN
# 4    gs://cmip6/CMIP6/CMIP/AWI/AWI-CM-1-1-MR/histor...             NaN
# ..                                                 ...             ...
# 388  gs://cmip6/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ss...             NaN
# 389  gs://cmip6/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ss...             NaN
# 390  gs://cmip6/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ss...             NaN
# 391  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
# 392  gs://cmip6/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ss...             NaN
#
#       version
# 0    20181015
# 1    20181116
# 2    20181119
# 3    20181126
# 4    20181218
# ..        ...
# 388  20210907
# 389  20210907
# 390  20210907
# 391  20210907
# 392  20210907
#
# [393 rows x 11 columns]

# %% [markdown]
# Train the model

# %%
model.fit(train_subset, obs_subset)
# model.fit(train_subset, train_subset)
display(model, model._models)
# Out:
# <skdownscale.PointWiseDownscaler>
#   Fit Status: True
#   Model:
#     PureAnalog(n_analogs=1)
# <xarray.DataArray 'tasmax' (lat: 951, lon: 2402)>
# dask.array<<this-array>-_fit_wrapper, shape=(951, 2402), dtype=object, chunksize=(10, 10), chunktype=numpy.ndarray>
# Coordinates:
#   * lat      (lat) float64 6.5 6.48 6.46 6.44 ... -12.44 -12.46 -12.48 -12.5
#   * lon      (lon) float64 94.5 94.52 94.54 94.56 ... 142.5 142.5 142.5 142.5

# %% [markdown]
# Downscale into future

# %%
predicted = model.predict(holdout_subset).load()
nowdays = model.predict(train_subset).load()
# Out:
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56763' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 265, in connect
#     addrinfo = await self.resolver.resolve(host, port, af)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56766' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 265, in connect
#     addrinfo = await self.resolver.resolve(host, port, af)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56778' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 265, in connect
#     addrinfo = await self.resolver.resolve(host, port, af)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56775' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56788' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 265, in connect
#     addrinfo = await self.resolver.resolve(host, port, af)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56798' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56812' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56818' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56829' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56847' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56854' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56869' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56875' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56891' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56898' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback functools.partial(<bound method IOLoop._discard_future_result of <zmq.eventloop.ioloop.ZMQIOLoop object at 0x7efb903795e0>>, <Task finished name='Task-56916' coro=<Cluster._sync_cluster_info() done, defined at /home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py:98> exception=OSError('Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s')>)
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 391, in connect
#     stream = await self.client.connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/tcpclient.py", line 275, in connect
#     af, addr, stream = await connector.start(connect_timeout=timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 492, in wait_for
#     fut.result()
# asyncio.exceptions.CancelledError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 494, in wait_for
#     raise exceptions.TimeoutError() from exc
# asyncio.exceptions.TimeoutError
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 741, in _run_callback
#     ret = callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 765, in _discard_future_result
#     future.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/deploy/cluster.py", line 99, in _sync_cluster_info
#     await self.scheduler_comm.set_metadata(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 796, in send_recv_from_rpc
#     comm = await self.live_comm()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 753, in live_comm
#     comm = await connect(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 307, in connect
#     raise OSError(
# OSError: Timed out trying to connect to tcp://127.0.0.1:39647 after 30 s
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fee1e74b0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54558 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f6c6f8781f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54578 remote=tcp://127.0.0.1:39647> already closed.
# distributed.worker - WARNING - Heartbeat to scheduler failed
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 198, in read
#     frames_nbytes = await stream.read_bytes(fmt_size)
# tornado.iostream.StreamClosedError: Stream is closed
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 1001, in heartbeat
#     response = await retry_operation(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 874, in send_recv_from_rpc
#     result = await send_recv(comm=comm, op=key, **kwargs)
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/core.py", line 651, in send_recv
#     response = await comm.read(deserializers=deserializers)
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 214, in read
#     convert_stream_closed_error(self, e)
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 128, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <TCP (closed) ConnectionPool.heartbeat_worker local=tcp://127.0.0.1:58188 remote=tcp://127.0.0.1:39647>: Stream is closed
# distributed.worker - ERROR - Worker stream died during communication: tcp://146.179.44.32:42761
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/core.py", line 283, in connect
#     comm = await asyncio.wait_for(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/asyncio/tasks.py", line 481, in wait_for
#     return fut.result()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 403, in connect
#     convert_stream_closed_error(self, e)
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/comm/tcp.py", line 126, in convert_stream_closed_error
#     raise CommClosedError(f"in {obj}: {exc.__class__.__name__}: {exc}") from exc
# distributed.comm.core.CommClosedError: in <distributed.comm.tcp.TCPConnector object at 0x7efc1f23f4f0>: ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 2387, in gather_dep
#     response = await get_data_from_worker(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 3759, in get_data_from_worker
#     return await retry_operation(_get_data, operation="get_data_from_worker")
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/utils_comm.py", line 385, in retry_operation
#     return await retry(
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/utils_comm.py", line 370, in retry
#     return await coro()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 3736, in _get_data
# ...
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f915e76a1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:58168 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f653f55c0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f915e76a1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:58168 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f653f55c0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f915e76a1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:58168 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f653f55c0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f915e76a1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:58168 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f653f55c0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f915e76a1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:58168 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f653f55c0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f915e76a1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:58168 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7f653f55c0d0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54562 remote=tcp://127.0.0.1:39647> already closed.
# tornado.application - ERROR - Exception in callback <function Worker.__init__.<locals>.<lambda> at 0x7fa62928d1f0>
# Traceback (most recent call last):
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/tornado/ioloop.py", line 905, in _run
#     return self.callback()
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/worker.py", line 751, in <lambda>
#     lambda: self.batched_stream.send({"op": "keep-alive"}), 60000
#   File "/home/sw1013/anaconda3/envs/downscale/lib/python3.9/site-packages/distributed/batched.py", line 136, in send
#     raise CommClosedError(f"Comm {self.comm!r} already closed.")
# distributed.comm.core.CommClosedError: Comm <TCP (closed) Worker->Scheduler local=tcp://127.0.0.1:54570 remote=tcp://127.0.0.1:39647> already closed.

# %%
predicted_IND,nowdays_IND = predicted,nowdays

# %% [markdown]
# ## PLOT

# %%
# modified from

import regionmask
import geopandas as gpd

PATH_TO_SHAPEFILE = '../../borders/gadm36.shp'
countries = gpd.read_file(PATH_TO_SHAPEFILE)

# %%
countries_select = countries[countries.NAME_0=='Thailand'].geometry

countries_mask_poly = regionmask.Regions(name = 'NAME_0', outlines = list(countries_select.geometry.values[i] for i in range(0,countries_select.shape[0])))

mask = countries_mask_poly.mask(predicted_IND.isel(time = 0), lat_name='lat', lon_name='lon')

tmp_var = predicted_IND.mean('time').where(~np.isnan(mask))

# mask_algeria = mask.where(mask == 'MYS')

plt.figure(figsize=(16,8))
ax = plt.axes()
tmp_var.plot(ax=ax,cmap='hot_r')
countries_select.plot(ax = ax, alpha = 0.8, facecolor = 'none', lw = 0)
